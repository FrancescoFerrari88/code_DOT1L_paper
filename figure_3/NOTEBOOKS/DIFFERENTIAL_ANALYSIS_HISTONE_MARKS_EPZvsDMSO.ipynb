# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import seaborn as sns
import scipy.stats as st
import RELACS as rel
sns.set_style("white")
sns.set_context("paper")
# %load_ext rpy2.ipython
# %matplotlib inline
# Out:
# /package/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /package/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # NPC48h

# %%
# %%bash
#
# ### PERFORM DESEQ2 DIFFERENTIAL ANALYSIS FOR EACH MARK ###
# # H3K4me3 #
#
# pipe_DiffPeaks.sh ../INPUT_DATA/info_data_H3K4me3_NPC48h.txt ../../figure_1-2/INPUT_DATA/NPC48h_H3K4me3_BAMPE-BAM_consensusPeaks.bed.cleaned.bed ../INTERMEDIATE_FILES/NPC48h_DIFF_H3K4me3
# Out:
# bams: /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_iNPC/filtered_bam/iNPC_DMSO_rep1_H3K4me3_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_iNPC/filtered_bam/iNPC_DMSO_rep2_H3K4me3_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_iNPC/filtered_bam/iNPC_EPZ_rep1_H3K4me3_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_iNPC/filtered_bam/iNPC_EPZ_rep2_H3K4me3_merged.filtered.bam
# mark: H3K4me3
# outdir: ../INTERMEDIATE_FILES/NPC48h_DIFF_H3K4me3
# [1] TRUE
# null device
#           1
# null device
#           1
# null device
#           1
# ...

# %%
# %%bash
#
# ### PERFORM DESEQ2 DIFFERENTIAL ANALYSIS FOR EACH MARK ###
# # H3K27ac #
#
# pipe_DiffPeaks.sh ../INPUT_DATA/info_data_H3K27ac_NPC48h.txt ../../figure_1-2/INPUT_DATA/NPC48h_H3K27ac_BAMPE-BAM_consensusPeaks.bed.cleaned.bed ../INTERMEDIATE_FILES/NPC48h_DIFF_H3K27ac
# Out:
# bams: /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_iNPC/filtered_bam/iNPC_DMSO_rep1_H3K27ac_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_iNPC/filtered_bam/iNPC_DMSO_rep2_H3K27ac_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_iNPC/filtered_bam/iNPC_EPZ_rep1_H3K27ac_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_iNPC/filtered_bam/iNPC_EPZ_rep2_H3K27ac_merged.filtered.bam
# mark: H3K27ac
# outdir: ../INTERMEDIATE_FILES/NPC48h_DIFF_H3K27ac
# [1] TRUE
# null device
#           1
# null device
#           1
# null device
#           1
# ...

# %% [markdown]
# # mESC

# %%
# %%bash
#
# ### PERFORM DESEQ2 DIFFERENTIAL ANALYSIS FOR EACH MARK ###
# # H3K4me3 #
#
# pipe_DiffPeaks.sh ../INPUT_DATA/info_data_H3K4me3_mESC.txt ../../figure_1-2/INPUT_DATA/mESC_H3K4me3_BAMPE-BAM_consensusPeaks.bed.cleaned.bed ../INTERMEDIATE_FILES/mESC_DIFF_H3K4me3
# Out:
# bams: /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_mESC/filtered_bam/mESC_DMSO_rep1_H3K4me3_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_mESC/filtered_bam/mESC_DMSO_rep2_H3K4me3_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_mESC/filtered_bam/mESC_EPZ_rep1_H3K4me3_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_mESC/filtered_bam/mESC_EPZ_rep2_H3K4me3_merged.filtered.bam
# mark: H3K4me3
# outdir: ../INTERMEDIATE_FILES/mESC_DIFF_H3K4me3
# [1] TRUE
# null device
#           1
# null device
#           1
# null device
#           1
# ...

# %%
# %%bash
#
# ### PERFORM DESEQ2 DIFFERENTIAL ANALYSIS FOR EACH MARK ###
# # H3K27ac #
#
# pipe_DiffPeaks.sh ../INPUT_DATA/info_data_H3K27ac_mESC.txt ../../figure_1-2/INPUT_DATA/mESC_H3K27ac_BAMPE-BAM_consensusPeaks.bed.cleaned.bed ../INTERMEDIATE_FILES/mESC_DIFF_H3K27ac
# Out:
# bams: /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_mESC/filtered_bam/mESC_DMSO_rep1_H3K27ac_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_mESC/filtered_bam/mESC_DMSO_rep2_H3K27ac_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_mESC/filtered_bam/mESC_EPZ_rep1_H3K27ac_merged.filtered.bam /data/manke/group/ferrari/PhD_project/reference_datasets/Ferrari_mESC-iNPC_DMSOvsEPZ_fullEpigenomes_MERGED/output_DNA-mapping_snakepipe_mESC/filtered_bam/mESC_EPZ_rep2_H3K27ac_merged.filtered.bam
# mark: H3K27ac
# outdir: ../INTERMEDIATE_FILES/mESC_DIFF_H3K27ac
# [1] TRUE
# null device
#           1
# null device
#           1
# null device
#           1
# ...
